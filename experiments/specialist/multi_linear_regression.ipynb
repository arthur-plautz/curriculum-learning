# %%
from sklearn.model_selection import train_test_split
from specialist_data import transformed

# split train/test data
X_train, X_test, y_train, y_test = train_test_split(transformed.X, transformed.performance, test_size=0.33, random_state=42)

# %%
from graph_utils import df_single_scatters

df = transformed.data

X = transformed.X.columns
y = 'performance'

df_single_scatters(df, X, y)

# %%
import seaborn as sns

corr = df.corr()

sns.heatmap(corr, center=True)
# Out:
# <AxesSubplot:>

# %%
import statsmodels.api as sm

model = sm.OLS(y_train, sm.add_constant(X_train)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            performance   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                              3.460
# Date:                Wed, 20 Oct 2021   Prob (F-statistic):                     0.00203
# Time:                        22:18:26   Log-Likelihood:                     -2.2113e+05
# No. Observations:               42880   AIC:                                  4.423e+05
# Df Residuals:                   42874   BIC:                                  4.423e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
