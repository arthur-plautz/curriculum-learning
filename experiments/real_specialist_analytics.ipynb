# %%
from models.experiments.real_specialist import RealSpecialistExperiment
from definitions import MANAGER_FOLDER
from graphs import precision_recall_graph, score_graph

seeds = ['s6', 's7', 's8', 's9', 's10']
batch_sizes = [10, 20, 30]

experiment = RealSpecialistExperiment(MANAGER_FOLDER, seeds, batch_sizes)

# %%
import seaborn as sns

sns.color_palette("mako", as_cmap=True)

summary = experiment.get_summary()
score_graph(batch_sizes, summary, seeds)

metrics_columns = ['cm_true_positive','cm_false_positive','cm_false_negative','cm_true_negative']
metrics = experiment.get_stats(metrics_columns)

precision_recall_graph(metrics, batch_sizes, seeds)
